# %%
import tensorflow as tf
#
from tensorflow.keras.applications import EfficientNetV2S
from tensorflow.keras.layers import Input, Dense, Flatten
from tensorflow.keras import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy
#
import numpy as np

# %%
nsize = 32
batch_size = 32
#
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
#
x_train = np.expand_dims(x_train, axis=-1)
x_train = np.repeat(x_train, 3, axis=-1)
x_train = x_train.astype('float32') / 255
x_train = tf.image.resize(x_train, [nsize,nsize])
#
y_train = tf.keras.utils.to_categorical(y_train, num_classes = 10)
#
x_test = np.expand_dims(x_test, axis=-1)
x_test = np.repeat(x_test, 3, axis=-1)
x_test = x_test.astype('float32') / 255
x_test = tf.image.resize(x_test, [nsize,nsize])
#
y_test = tf.keras.utils.to_categorical(y_test, num_classes = 10)
# Out:
# 2023-05-05 19:27:44.261259: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-05 19:27:45.767153: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22833 MB memory:  -> device: 0, name: Quadro RTX 6000, pci bus id: 0000:1a:00.0, compute capability: 7.5
# 2023-05-05 19:27:45.768319: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 22833 MB memory:  -> device: 1, name: Quadro RTX 6000, pci bus id: 0000:67:00.0, compute capability: 7.5
# 2023-05-05 19:27:45.771982: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 22428 MB memory:  -> device: 2, name: Quadro RTX 6000, pci bus id: 0000:68:00.0, compute capability: 7.5

# %%
strategy = tf.distribute.MirroredStrategy()
print("Number of devices: {}".format(strategy.num_replicas_in_sync))
#
# Open a strategy scope
with strategy.scope():
    """
    Load the Model
    """
    #
    input_tensor = Input(shape=(nsize,nsize,3))
    #
    stem_model = EfficientNetV2S(
        include_top=False,
        weights='imagenet',
        input_tensor=input_tensor,
        input_shape=None,
        classifier_activation=None,
        include_preprocessing=True
    )
    #
    flatten = Flatten()(stem_model.output)
    dense1 = Dense(4080, activation='relu')(flatten)
    dense2 = Dense(4080, activation='relu')(dense1)
    output_tensor = Dense(10,activation='softmax')(dense2)
    #
    model = Model(input_tensor, output_tensor)
    #
    model.summary()
    """
    Compile the Model, dependent on the loss function defined in custom_utils.py
    """
    #
    model.compile(
        optimizer = Adam(learning_rate=0.0001),
        loss = CategoricalCrossentropy(),
        metrics = ["acc"]
    )

model.fit(x_train, y_train, epochs=1)
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1', '/job:localhost/replica:0/task:0/device:GPU:2')
# Number of devices: 3
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  rescaling (Rescaling)          (None, 32, 32, 3)    0           ['input_1[0][0]']
#
#  stem_conv (Conv2D)             (None, 16, 16, 24)   648         ['rescaling[0][0]']
#
#  stem_bn (BatchNormalization)   (None, 16, 16, 24)   96          ['stem_conv[0][0]']
#
#  stem_activation (Activation)   (None, 16, 16, 24)   0           ['stem_bn[0][0]']
#
#  block1a_project_conv (Conv2D)  (None, 16, 16, 24)   5184        ['stem_activation[0][0]']
#
#  block1a_project_bn (BatchNorma  (None, 16, 16, 24)  96          ['block1a_project_conv[0][0]']
#  lization)
#
#  block1a_project_activation (Ac  (None, 16, 16, 24)  0           ['block1a_project_bn[0][0]']
#  tivation)
#
#  block1a_add (Add)              (None, 16, 16, 24)   0           ['block1a_project_activation[0][0
#                                                                  ]',
#                                                                   'stem_activation[0][0]']
#
#  block1b_project_conv (Conv2D)  (None, 16, 16, 24)   5184        ['block1a_add[0][0]']
#
#  block1b_project_bn (BatchNorma  (None, 16, 16, 24)  96          ['block1b_project_conv[0][0]']
#  lization)
#
#  block1b_project_activation (Ac  (None, 16, 16, 24)  0           ['block1b_project_bn[0][0]']
#  tivation)
#
#  block1b_drop (Dropout)         (None, 16, 16, 24)   0           ['block1b_project_activation[0][0
#                                                                  ]']
#
#  block1b_add (Add)              (None, 16, 16, 24)   0           ['block1b_drop[0][0]',
#                                                                   'block1a_add[0][0]']
#
#  block2a_expand_conv (Conv2D)   (None, 8, 8, 96)     20736       ['block1b_add[0][0]']
#
#  block2a_expand_bn (BatchNormal  (None, 8, 8, 96)    384         ['block2a_expand_conv[0][0]']
#  ization)
#
#  block2a_expand_activation (Act  (None, 8, 8, 96)    0           ['block2a_expand_bn[0][0]']
#  ivation)
#
#  block2a_project_conv (Conv2D)  (None, 8, 8, 48)     4608        ['block2a_expand_activation[0][0]
#                                                                  ']
#
#  block2a_project_bn (BatchNorma  (None, 8, 8, 48)    192         ['block2a_project_conv[0][0]']
#  lization)
#
#  block2b_expand_conv (Conv2D)   (None, 8, 8, 192)    82944       ['block2a_project_bn[0][0]']
#
#  block2b_expand_bn (BatchNormal  (None, 8, 8, 192)   768         ['block2b_expand_conv[0][0]']
#  ization)
#
#  block2b_expand_activation (Act  (None, 8, 8, 192)   0           ['block2b_expand_bn[0][0]']
#  ivation)
#
#  block2b_project_conv (Conv2D)  (None, 8, 8, 48)     9216        ['block2b_expand_activation[0][0]
#                                                                  ']
#
#  block2b_project_bn (BatchNorma  (None, 8, 8, 48)    192         ['block2b_project_conv[0][0]']
#  lization)
#  block2b_drop (Dropout)         (None, 8, 8, 48)     0           ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)              (None, 8, 8, 48)     0           ['block2b_drop[0][0]',
#                                                                   'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2D)   (None, 8, 8, 192)    82944       ['block2b_add[0][0]']
#
#  block2c_expand_bn (BatchNormal  (None, 8, 8, 192)   768         ['block2c_expand_conv[0][0]']
#  ization)
#
#  block2c_expand_activation (Act  (None, 8, 8, 192)   0           ['block2c_expand_bn[0][0]']
#  ivation)
#
#  block2c_project_conv (Conv2D)  (None, 8, 8, 48)     9216        ['block2c_expand_activation[0][0]
#                                                                  ']
#
#  block2c_project_bn (BatchNorma  (None, 8, 8, 48)    192         ['block2c_project_conv[0][0]']
#  lization)
#
#  block2c_drop (Dropout)         (None, 8, 8, 48)     0           ['block2c_project_bn[0][0]']
#
#  block2c_add (Add)              (None, 8, 8, 48)     0           ['block2c_drop[0][0]',
#                                                                   'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2D)   (None, 8, 8, 192)    82944       ['block2c_add[0][0]']
#
#  block2d_expand_bn (BatchNormal  (None, 8, 8, 192)   768         ['block2d_expand_conv[0][0]']
#  ization)
#
#  block2d_expand_activation (Act  (None, 8, 8, 192)   0           ['block2d_expand_bn[0][0]']
#  ivation)
#
#  block2d_project_conv (Conv2D)  (None, 8, 8, 48)     9216        ['block2d_expand_activation[0][0]
#                                                                  ']
#
#  block2d_project_bn (BatchNorma  (None, 8, 8, 48)    192         ['block2d_project_conv[0][0]']
#  lization)
#
#  block2d_drop (Dropout)         (None, 8, 8, 48)     0           ['block2d_project_bn[0][0]']
#
#  block2d_add (Add)              (None, 8, 8, 48)     0           ['block2d_drop[0][0]',
#                                                                   'block2c_add[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, 4, 4, 192)    82944       ['block2d_add[0][0]']
#
#  block3a_expand_bn (BatchNormal  (None, 4, 4, 192)   768         ['block3a_expand_conv[0][0]']
#  ization)
#
#  block3a_expand_activation (Act  (None, 4, 4, 192)   0           ['block3a_expand_bn[0][0]']
#  ivation)
#
#  block3a_project_conv (Conv2D)  (None, 4, 4, 64)     12288       ['block3a_expand_activation[0][0]
#                                                                  ']
#
#  block3a_project_bn (BatchNorma  (None, 4, 4, 64)    256         ['block3a_project_conv[0][0]']
#  lization)
#
#  block3b_expand_conv (Conv2D)   (None, 4, 4, 256)    147456      ['block3a_project_bn[0][0]']
#
#  block3b_expand_bn (BatchNormal  (None, 4, 4, 256)   1024        ['block3b_expand_conv[0][0]']
#  ization)
#
#  block3b_expand_activation (Act  (None, 4, 4, 256)   0           ['block3b_expand_bn[0][0]']
#  ivation)
#
#  block3b_project_conv (Conv2D)  (None, 4, 4, 64)     16384       ['block3b_expand_activation[0][0]
#                                                                  ']
#
#  block3b_project_bn (BatchNorma  (None, 4, 4, 64)    256         ['block3b_project_conv[0][0]']
#  lization)
#
#  block3b_drop (Dropout)         (None, 4, 4, 64)     0           ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)              (None, 4, 4, 64)     0           ['block3b_drop[0][0]',
#                                                                   'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2D)   (None, 4, 4, 256)    147456      ['block3b_add[0][0]']
#
#  block3c_expand_bn (BatchNormal  (None, 4, 4, 256)   1024        ['block3c_expand_conv[0][0]']
#  ization)
#
#  block3c_expand_activation (Act  (None, 4, 4, 256)   0           ['block3c_expand_bn[0][0]']
#  ivation)
#
#  block3c_project_conv (Conv2D)  (None, 4, 4, 64)     16384       ['block3c_expand_activation[0][0]
#                                                                  ']
#
#  block3c_project_bn (BatchNorma  (None, 4, 4, 64)    256         ['block3c_project_conv[0][0]']
#  lization)
#
#  block3c_drop (Dropout)         (None, 4, 4, 64)     0           ['block3c_project_bn[0][0]']
#
#  block3c_add (Add)              (None, 4, 4, 64)     0           ['block3c_drop[0][0]',
#                                                                   'block3b_add[0][0]']
#
#  block3d_expand_conv (Conv2D)   (None, 4, 4, 256)    147456      ['block3c_add[0][0]']
#
#  block3d_expand_bn (BatchNormal  (None, 4, 4, 256)   1024        ['block3d_expand_conv[0][0]']
#  ization)
#
#  block3d_expand_activation (Act  (None, 4, 4, 256)   0           ['block3d_expand_bn[0][0]']
#  ivation)
#
#  block3d_project_conv (Conv2D)  (None, 4, 4, 64)     16384       ['block3d_expand_activation[0][0]
#                                                                  ']
#
#  block3d_project_bn (BatchNorma  (None, 4, 4, 64)    256         ['block3d_project_conv[0][0]']
#  lization)
#
#  block3d_drop (Dropout)         (None, 4, 4, 64)     0           ['block3d_project_bn[0][0]']
#
#  block3d_add (Add)              (None, 4, 4, 64)     0           ['block3d_drop[0][0]',
#                                                                   'block3c_add[0][0]']
#
#  block4a_expand_conv (Conv2D)   (None, 4, 4, 256)    16384       ['block3d_add[0][0]']
#
#  block4a_expand_bn (BatchNormal  (None, 4, 4, 256)   1024        ['block4a_expand_conv[0][0]']
#  ization)
#
#  block4a_expand_activation (Act  (None, 4, 4, 256)   0           ['block4a_expand_bn[0][0]']
#  ivation)
#
#  block4a_dwconv2 (DepthwiseConv  (None, 2, 2, 256)   2304        ['block4a_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4a_bn (BatchNormalization  (None, 2, 2, 256)   1024        ['block4a_dwconv2[0][0]']
#  )
#
#  block4a_activation (Activation  (None, 2, 2, 256)   0           ['block4a_bn[0][0]']
#  )
#
#  block4a_se_squeeze (GlobalAver  (None, 256)         0           ['block4a_activation[0][0]']
#  agePooling2D)
#
#  block4a_se_reshape (Reshape)   (None, 1, 1, 256)    0           ['block4a_se_squeeze[0][0]']
#
#  block4a_se_reduce (Conv2D)     (None, 1, 1, 16)     4112        ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)     (None, 1, 1, 256)    4352        ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multiply)   (None, 2, 2, 256)    0           ['block4a_activation[0][0]',
#                                                                   'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv2D)  (None, 2, 2, 128)    32768       ['block4a_se_excite[0][0]']
#
#  block4a_project_bn (BatchNorma  (None, 2, 2, 128)   512         ['block4a_project_conv[0][0]']
#  lization)
#
#  block4b_expand_conv (Conv2D)   (None, 2, 2, 512)    65536       ['block4a_project_bn[0][0]']
#
#  block4b_expand_bn (BatchNormal  (None, 2, 2, 512)   2048        ['block4b_expand_conv[0][0]']
#  ization)
#
#  block4b_expand_activation (Act  (None, 2, 2, 512)   0           ['block4b_expand_bn[0][0]']
#  ivation)
#
#  block4b_dwconv2 (DepthwiseConv  (None, 2, 2, 512)   4608        ['block4b_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4b_bn (BatchNormalization  (None, 2, 2, 512)   2048        ['block4b_dwconv2[0][0]']
#  )
#
#  block4b_activation (Activation  (None, 2, 2, 512)   0           ['block4b_bn[0][0]']
#  )
#
#  block4b_se_squeeze (GlobalAver  (None, 512)         0           ['block4b_activation[0][0]']
#  agePooling2D)
#
#  block4b_se_reshape (Reshape)   (None, 1, 1, 512)    0           ['block4b_se_squeeze[0][0]']
#
#  block4b_se_reduce (Conv2D)     (None, 1, 1, 32)     16416       ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)     (None, 1, 1, 512)    16896       ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multiply)   (None, 2, 2, 512)    0           ['block4b_activation[0][0]',
#                                                                   'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv2D)  (None, 2, 2, 128)    65536       ['block4b_se_excite[0][0]']
#
#  block4b_project_bn (BatchNorma  (None, 2, 2, 128)   512         ['block4b_project_conv[0][0]']
#  lization)
#
#  block4b_drop (Dropout)         (None, 2, 2, 128)    0           ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)              (None, 2, 2, 128)    0           ['block4b_drop[0][0]',
#                                                                   'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2D)   (None, 2, 2, 512)    65536       ['block4b_add[0][0]']
#
#  block4c_expand_bn (BatchNormal  (None, 2, 2, 512)   2048        ['block4c_expand_conv[0][0]']
#  ization)
#
#  block4c_expand_activation (Act  (None, 2, 2, 512)   0           ['block4c_expand_bn[0][0]']
#  ivation)
#
#  block4c_dwconv2 (DepthwiseConv  (None, 2, 2, 512)   4608        ['block4c_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4c_bn (BatchNormalization  (None, 2, 2, 512)   2048        ['block4c_dwconv2[0][0]']
#  )
#
#  block4c_activation (Activation  (None, 2, 2, 512)   0           ['block4c_bn[0][0]']
#  )
#
#  block4c_se_squeeze (GlobalAver  (None, 512)         0           ['block4c_activation[0][0]']
#  agePooling2D)
#
#  block4c_se_reshape (Reshape)   (None, 1, 1, 512)    0           ['block4c_se_squeeze[0][0]']
#
#  block4c_se_reduce (Conv2D)     (None, 1, 1, 32)     16416       ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)     (None, 1, 1, 512)    16896       ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multiply)   (None, 2, 2, 512)    0           ['block4c_activation[0][0]',
#                                                                   'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv2D)  (None, 2, 2, 128)    65536       ['block4c_se_excite[0][0]']
#
#  block4c_project_bn (BatchNorma  (None, 2, 2, 128)   512         ['block4c_project_conv[0][0]']
#  lization)
#
#  block4c_drop (Dropout)         (None, 2, 2, 128)    0           ['block4c_project_bn[0][0]']
#
#  block4c_add (Add)              (None, 2, 2, 128)    0           ['block4c_drop[0][0]',
#                                                                   'block4b_add[0][0]']
#
#  block4d_expand_conv (Conv2D)   (None, 2, 2, 512)    65536       ['block4c_add[0][0]']
#
#  block4d_expand_bn (BatchNormal  (None, 2, 2, 512)   2048        ['block4d_expand_conv[0][0]']
#  ization)
#
#  block4d_expand_activation (Act  (None, 2, 2, 512)   0           ['block4d_expand_bn[0][0]']
#  ivation)
#
#  block4d_dwconv2 (DepthwiseConv  (None, 2, 2, 512)   4608        ['block4d_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4d_bn (BatchNormalization  (None, 2, 2, 512)   2048        ['block4d_dwconv2[0][0]']
#  )
#
#  block4d_activation (Activation  (None, 2, 2, 512)   0           ['block4d_bn[0][0]']
#  )
#
#  block4d_se_squeeze (GlobalAver  (None, 512)         0           ['block4d_activation[0][0]']
#  agePooling2D)
#
#  block4d_se_reshape (Reshape)   (None, 1, 1, 512)    0           ['block4d_se_squeeze[0][0]']
#
#  block4d_se_reduce (Conv2D)     (None, 1, 1, 32)     16416       ['block4d_se_reshape[0][0]']
#
#  block4d_se_expand (Conv2D)     (None, 1, 1, 512)    16896       ['block4d_se_reduce[0][0]']
#
#  block4d_se_excite (Multiply)   (None, 2, 2, 512)    0           ['block4d_activation[0][0]',
#                                                                   'block4d_se_expand[0][0]']
#
#  block4d_project_conv (Conv2D)  (None, 2, 2, 128)    65536       ['block4d_se_excite[0][0]']
#
#  block4d_project_bn (BatchNorma  (None, 2, 2, 128)   512         ['block4d_project_conv[0][0]']
#  lization)
#
#  block4d_drop (Dropout)         (None, 2, 2, 128)    0           ['block4d_project_bn[0][0]']
#
#  block4d_add (Add)              (None, 2, 2, 128)    0           ['block4d_drop[0][0]',
#                                                                   'block4c_add[0][0]']
#
#  block4e_expand_conv (Conv2D)   (None, 2, 2, 512)    65536       ['block4d_add[0][0]']
#
#  block4e_expand_bn (BatchNormal  (None, 2, 2, 512)   2048        ['block4e_expand_conv[0][0]']
#  ization)
#
#  block4e_expand_activation (Act  (None, 2, 2, 512)   0           ['block4e_expand_bn[0][0]']
#  ivation)
#
#  block4e_dwconv2 (DepthwiseConv  (None, 2, 2, 512)   4608        ['block4e_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4e_bn (BatchNormalization  (None, 2, 2, 512)   2048        ['block4e_dwconv2[0][0]']
#  )
#
#  block4e_activation (Activation  (None, 2, 2, 512)   0           ['block4e_bn[0][0]']
#  )
#
#  block4e_se_squeeze (GlobalAver  (None, 512)         0           ['block4e_activation[0][0]']
#  agePooling2D)
#
#  block4e_se_reshape (Reshape)   (None, 1, 1, 512)    0           ['block4e_se_squeeze[0][0]']
#
#  block4e_se_reduce (Conv2D)     (None, 1, 1, 32)     16416       ['block4e_se_reshape[0][0]']
#
#  block4e_se_expand (Conv2D)     (None, 1, 1, 512)    16896       ['block4e_se_reduce[0][0]']
#
#  block4e_se_excite (Multiply)   (None, 2, 2, 512)    0           ['block4e_activation[0][0]',
#                                                                   'block4e_se_expand[0][0]']
#
#  block4e_project_conv (Conv2D)  (None, 2, 2, 128)    65536       ['block4e_se_excite[0][0]']
#
#  block4e_project_bn (BatchNorma  (None, 2, 2, 128)   512         ['block4e_project_conv[0][0]']
#  lization)
#
#  block4e_drop (Dropout)         (None, 2, 2, 128)    0           ['block4e_project_bn[0][0]']
#
#  block4e_add (Add)              (None, 2, 2, 128)    0           ['block4e_drop[0][0]',
#                                                                   'block4d_add[0][0]']
#
#  block4f_expand_conv (Conv2D)   (None, 2, 2, 512)    65536       ['block4e_add[0][0]']
#
#  block4f_expand_bn (BatchNormal  (None, 2, 2, 512)   2048        ['block4f_expand_conv[0][0]']
#  ization)
#
#  block4f_expand_activation (Act  (None, 2, 2, 512)   0           ['block4f_expand_bn[0][0]']
#  ivation)
#
#  block4f_dwconv2 (DepthwiseConv  (None, 2, 2, 512)   4608        ['block4f_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4f_bn (BatchNormalization  (None, 2, 2, 512)   2048        ['block4f_dwconv2[0][0]']
#  )
#
#  block4f_activation (Activation  (None, 2, 2, 512)   0           ['block4f_bn[0][0]']
#  )
#
#  block4f_se_squeeze (GlobalAver  (None, 512)         0           ['block4f_activation[0][0]']
#  agePooling2D)
#
#  block4f_se_reshape (Reshape)   (None, 1, 1, 512)    0           ['block4f_se_squeeze[0][0]']
#
#  block4f_se_reduce (Conv2D)     (None, 1, 1, 32)     16416       ['block4f_se_reshape[0][0]']
#
#  block4f_se_expand (Conv2D)     (None, 1, 1, 512)    16896       ['block4f_se_reduce[0][0]']
#
#  block4f_se_excite (Multiply)   (None, 2, 2, 512)    0           ['block4f_activation[0][0]',
#                                                                   'block4f_se_expand[0][0]']
#
#  block4f_project_conv (Conv2D)  (None, 2, 2, 128)    65536       ['block4f_se_excite[0][0]']
#
#  block4f_project_bn (BatchNorma  (None, 2, 2, 128)   512         ['block4f_project_conv[0][0]']
#  lization)
#
#  block4f_drop (Dropout)         (None, 2, 2, 128)    0           ['block4f_project_bn[0][0]']
#
#  block4f_add (Add)              (None, 2, 2, 128)    0           ['block4f_drop[0][0]',
#                                                                   'block4e_add[0][0]']
#
#  block5a_expand_conv (Conv2D)   (None, 2, 2, 768)    98304       ['block4f_add[0][0]']
#
#  block5a_expand_bn (BatchNormal  (None, 2, 2, 768)   3072        ['block5a_expand_conv[0][0]']
#  ization)
#
#  block5a_expand_activation (Act  (None, 2, 2, 768)   0           ['block5a_expand_bn[0][0]']
#  ivation)
#
#  block5a_dwconv2 (DepthwiseConv  (None, 2, 2, 768)   6912        ['block5a_expand_activation[0][0]
#  2D)                                                             ']
#
#  block5a_bn (BatchNormalization  (None, 2, 2, 768)   3072        ['block5a_dwconv2[0][0]']
#  )
#
#  block5a_activation (Activation  (None, 2, 2, 768)   0           ['block5a_bn[0][0]']
#  )
#
#  block5a_se_squeeze (GlobalAver  (None, 768)         0           ['block5a_activation[0][0]']
#  agePooling2D)
#
#  block5a_se_reshape (Reshape)   (None, 1, 1, 768)    0           ['block5a_se_squeeze[0][0]']
#
#  block5a_se_reduce (Conv2D)     (None, 1, 1, 32)     24608       ['block5a_se_reshape[0][0]']
#
#  block5a_se_expand (Conv2D)     (None, 1, 1, 768)    25344       ['block5a_se_reduce[0][0]']
#
#  block5a_se_excite (Multiply)   (None, 2, 2, 768)    0           ['block5a_activation[0][0]',
#                                                                   'block5a_se_expand[0][0]']
#
#  block5a_project_conv (Conv2D)  (None, 2, 2, 160)    122880      ['block5a_se_excite[0][0]']
#
#  block5a_project_bn (BatchNorma  (None, 2, 2, 160)   640         ['block5a_project_conv[0][0]']
#  lization)
#
#  block5b_expand_conv (Conv2D)   (None, 2, 2, 960)    153600      ['block5a_project_bn[0][0]']
#
#  block5b_expand_bn (BatchNormal  (None, 2, 2, 960)   3840        ['block5b_expand_conv[0][0]']
#  ization)
#
#  block5b_expand_activation (Act  (None, 2, 2, 960)   0           ['block5b_expand_bn[0][0]']
#  ivation)
#
#  block5b_dwconv2 (DepthwiseConv  (None, 2, 2, 960)   8640        ['block5b_expand_activation[0][0]
#  2D)                                                             ']
#
#  block5b_bn (BatchNormalization  (None, 2, 2, 960)   3840        ['block5b_dwconv2[0][0]']
#  )
#
#  block5b_activation (Activation  (None, 2, 2, 960)   0           ['block5b_bn[0][0]']
#  )
#
#  block5b_se_squeeze (GlobalAver  (None, 960)         0           ['block5b_activation[0][0]']
#  agePooling2D)
#
#  block5b_se_reshape (Reshape)   (None, 1, 1, 960)    0           ['block5b_se_squeeze[0][0]']
#
#  block5b_se_reduce (Conv2D)     (None, 1, 1, 40)     38440       ['block5b_se_reshape[0][0]']
#
#  block5b_se_expand (Conv2D)     (None, 1, 1, 960)    39360       ['block5b_se_reduce[0][0]']
#
#  block5b_se_excite (Multiply)   (None, 2, 2, 960)    0           ['block5b_activation[0][0]',
# ...
#
#  block6m_expand_activation (Act  (None, 1, 1, 1536)  0           ['block6m_expand_bn[0][0]']
#  ivation)
#
#  block6m_dwconv2 (DepthwiseConv  (None, 1, 1, 1536)  13824       ['block6m_expand_activation[0][0]
#  2D)                                                             ']
#
#  block6m_bn (BatchNormalization  (None, 1, 1, 1536)  6144        ['block6m_dwconv2[0][0]']
#  )
#
#  block6m_activation (Activation  (None, 1, 1, 1536)  0           ['block6m_bn[0][0]']
#  )
#
#  block6m_se_squeeze (GlobalAver  (None, 1536)        0           ['block6m_activation[0][0]']
#  agePooling2D)
#
#  block6m_se_reshape (Reshape)   (None, 1, 1, 1536)   0           ['block6m_se_squeeze[0][0]']
#
#  block6m_se_reduce (Conv2D)     (None, 1, 1, 64)     98368       ['block6m_se_reshape[0][0]']
#
#  block6m_se_expand (Conv2D)     (None, 1, 1, 1536)   99840       ['block6m_se_reduce[0][0]']
#
#  block6m_se_excite (Multiply)   (None, 1, 1, 1536)   0           ['block6m_activation[0][0]',
#                                                                   'block6m_se_expand[0][0]']
#
#  block6m_project_conv (Conv2D)  (None, 1, 1, 256)    393216      ['block6m_se_excite[0][0]']
#
#  block6m_project_bn (BatchNorma  (None, 1, 1, 256)   1024        ['block6m_project_conv[0][0]']
#  lization)
#
#  block6m_drop (Dropout)         (None, 1, 1, 256)    0           ['block6m_project_bn[0][0]']
#
#  block6m_add (Add)              (None, 1, 1, 256)    0           ['block6m_drop[0][0]',
#                                                                   'block6l_add[0][0]']
#
#  block6n_expand_conv (Conv2D)   (None, 1, 1, 1536)   393216      ['block6m_add[0][0]']
#
#  block6n_expand_bn (BatchNormal  (None, 1, 1, 1536)  6144        ['block6n_expand_conv[0][0]']
#  ization)
#
#  block6n_expand_activation (Act  (None, 1, 1, 1536)  0           ['block6n_expand_bn[0][0]']
#  ivation)
#
#  block6n_dwconv2 (DepthwiseConv  (None, 1, 1, 1536)  13824       ['block6n_expand_activation[0][0]
#  2D)                                                             ']
#
#  block6n_bn (BatchNormalization  (None, 1, 1, 1536)  6144        ['block6n_dwconv2[0][0]']
#  )
#
#  block6n_activation (Activation  (None, 1, 1, 1536)  0           ['block6n_bn[0][0]']
#  )
#
#  block6n_se_squeeze (GlobalAver  (None, 1536)        0           ['block6n_activation[0][0]']
#  agePooling2D)
#
#  block6n_se_reshape (Reshape)   (None, 1, 1, 1536)   0           ['block6n_se_squeeze[0][0]']
#
#  block6n_se_reduce (Conv2D)     (None, 1, 1, 64)     98368       ['block6n_se_reshape[0][0]']
#
#  block6n_se_expand (Conv2D)     (None, 1, 1, 1536)   99840       ['block6n_se_reduce[0][0]']
#
#  block6n_se_excite (Multiply)   (None, 1, 1, 1536)   0           ['block6n_activation[0][0]',
#                                                                   'block6n_se_expand[0][0]']
#
#  block6n_project_conv (Conv2D)  (None, 1, 1, 256)    393216      ['block6n_se_excite[0][0]']
#
#  block6n_project_bn (BatchNorma  (None, 1, 1, 256)   1024        ['block6n_project_conv[0][0]']
#  lization)
#
#  block6n_drop (Dropout)         (None, 1, 1, 256)    0           ['block6n_project_bn[0][0]']
#
#  block6n_add (Add)              (None, 1, 1, 256)    0           ['block6n_drop[0][0]',
#                                                                   'block6m_add[0][0]']
#
#  block6o_expand_conv (Conv2D)   (None, 1, 1, 1536)   393216      ['block6n_add[0][0]']
#
#  block6o_expand_bn (BatchNormal  (None, 1, 1, 1536)  6144        ['block6o_expand_conv[0][0]']
#  ization)
#
#  block6o_expand_activation (Act  (None, 1, 1, 1536)  0           ['block6o_expand_bn[0][0]']
#  ivation)
#
#  block6o_dwconv2 (DepthwiseConv  (None, 1, 1, 1536)  13824       ['block6o_expand_activation[0][0]
#  2D)                                                             ']
#
#  block6o_bn (BatchNormalization  (None, 1, 1, 1536)  6144        ['block6o_dwconv2[0][0]']
#  )
#
#  block6o_activation (Activation  (None, 1, 1, 1536)  0           ['block6o_bn[0][0]']
#  )
#
#  block6o_se_squeeze (GlobalAver  (None, 1536)        0           ['block6o_activation[0][0]']
#  agePooling2D)
#
#  block6o_se_reshape (Reshape)   (None, 1, 1, 1536)   0           ['block6o_se_squeeze[0][0]']
#
#  block6o_se_reduce (Conv2D)     (None, 1, 1, 64)     98368       ['block6o_se_reshape[0][0]']
#
#  block6o_se_expand (Conv2D)     (None, 1, 1, 1536)   99840       ['block6o_se_reduce[0][0]']
#
#  block6o_se_excite (Multiply)   (None, 1, 1, 1536)   0           ['block6o_activation[0][0]',
#                                                                   'block6o_se_expand[0][0]']
#
#  block6o_project_conv (Conv2D)  (None, 1, 1, 256)    393216      ['block6o_se_excite[0][0]']
#
#  block6o_project_bn (BatchNorma  (None, 1, 1, 256)   1024        ['block6o_project_conv[0][0]']
#  lization)
#
#  block6o_drop (Dropout)         (None, 1, 1, 256)    0           ['block6o_project_bn[0][0]']
#
#  block6o_add (Add)              (None, 1, 1, 256)    0           ['block6o_drop[0][0]',
#                                                                   'block6n_add[0][0]']
#
#  top_conv (Conv2D)              (None, 1, 1, 1280)   327680      ['block6o_add[0][0]']
#
#  top_bn (BatchNormalization)    (None, 1, 1, 1280)   5120        ['top_conv[0][0]']
#
#  top_activation (Activation)    (None, 1, 1, 1280)   0           ['top_bn[0][0]']
#
#  flatten (Flatten)              (None, 1280)         0           ['top_activation[0][0]']
#
#  dense (Dense)                  (None, 4080)         5226480     ['flatten[0][0]']
#
#  dense_1 (Dense)                (None, 4080)         16650480    ['dense[0][0]']
#
#  dense_2 (Dense)                (None, 10)           40810       ['dense_1[0][0]']
#
# ==================================================================================================
# Total params: 42,249,130
# Trainable params: 42,095,258
# Non-trainable params: 153,872
# __________________________________________________________________________________________________
# 2023-05-05 19:27:54.247167: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:776] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_9"
# op: "FlatMapDataset"
# input: "PrefetchDataset/_8"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "_cardinality"
#   value {
#     i: -2
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_slice_batch_indices_28340"
#     }
#   }
# }
# attr {
#   key: "metadata"
#   value {
#     s: "\n\020FlatMapDataset:4"
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: 32
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_INT64
#     }
#   }
# }
# experimental_type {
#   type_id: TFT_PRODUCT
#   args {
#     type_id: TFT_DATASET
#     args {
#       type_id: TFT_PRODUCT
#       args {
#         type_id: TFT_TENSOR
#         args {
#           type_id: TFT_INT64
#         }
#       }
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.
# INFO:tensorflow:batch_all_reduce: 456 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 456 all-reduces with algorithm = nccl, num_packs = 1
# 2023-05-05 19:29:04.036732: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8600
# 2023-05-05 19:29:04.873617: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8600
# 2023-05-05 19:29:05.071591: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8600
# 2023-05-05 19:29:05.357435: W tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-05-05 19:29:05.830358: W tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-05-05 19:29:06.330509: W tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 1875/1875 [==============================] - 376s 162ms/step - loss: 0.3627 - acc: 0.8857
